# %%
# 📦 SECTION 1: Imports and Configuration
import pynwb
import h5py
import remfile
from dandi.dandiapi import DandiAPIClient
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Download and read NWB files from a Dandiset, one file per subject
client = DandiAPIClient()
dandiset = client.get_dandiset("000253", "draft")

# Dictionary to store units tables from each file
units_tables = {}
file_metadata = {}

# Track subjects we've already processed
processed_subjects = set()

# Iterate over all assets in the dandiset
for asset in dandiset.get_assets():
    # Extract subject ID from path (assuming format like "sub-632485/...")
    path_parts = asset.path.split('/')
    if len(path_parts) > 0 and path_parts[0].startswith('sub-'):
        subject_id = path_parts[0]
        
        # Skip if we've already processed this subject
        if subject_id in processed_subjects:
            continue
            
        print(f"Processing file: {asset.path} (subject: {subject_id})")
        
        try:
            url = asset.download_url
            remote_file = remfile.File(url)
            h5_file = h5py.File(remote_file)
            io = pynwb.NWBHDF5IO(file=h5_file, load_namespaces=True)
            nwb = io.read()
            
            # Check if the file contains units
            if hasattr(nwb, 'units') and nwb.units is not None and len(nwb.units) > 0:
                units = nwb.units
                print(f"  Found units table with {len(units)} units")
                print(f"  Column names: {units.colnames}")
                
                # Create a unique key for this file using subject ID
                file_key = subject_id
                
                # Store the units table for this file
                units_tables[file_key] = units
                
                # Store metadata about this file
                file_metadata[file_key] = {
                    'path': asset.path,
                    'n_units': len(units),
                    'columns': units.colnames,
                    'subject_id': nwb.subject.subject_id if hasattr(nwb, 'subject') and nwb.subject else None,
                    'session_start_time': nwb.session_start_time if hasattr(nwb, 'session_start_time') else None
                }
                
                # # Example: Access units from specific file
                # if 'firing_rate' in units.colnames:
                #     firing_rates = units['firing_rate'][:]
                #     print(f"  Mean firing rate: {firing_rates.mean():.2f} Hz")
                
                # Mark this subject as processed
                processed_subjects.add(subject_id)
                
            else:
                print(f"  Skipping - no units table found or empty")
                
            # Clean up
            io.close()
            h5_file.close()
            
        except Exception as e:
            print(f"  Error processing {asset.path}: {e}")
            continue
    else:
        print(f"Skipping {asset.path} - doesn't match subject pattern")

print(f"\nProcessed {len(units_tables)} subjects with units tables")
print(f"Available subjects: {list(units_tables.keys())}")
# Out:
# Processing file: sub-621890/sub-621890_ses-1186358749_ogen.nwb (subject: sub-621890)
#   Found units table with 2446 units
#   Column names: ('cumulative_drift', 'local_index', 'firing_rate', 'l_ratio', 'silhouette_score', 'spread', 'cluster_id', 'velocity_above', 'recovery_slope', 'nn_miss_rate', 'nn_hit_rate', 'waveform_halfwidth', 'quality', 'peak_channel_id', 'isi_violations', 'amplitude_cutoff', 'd_prime', 'repolarization_slope', 'PT_ratio', 'snr', 'isolation_distance', 'amplitude', 'max_drift', 'waveform_duration', 'presence_ratio', 'velocity_below', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-632487/sub-632487_ses-1204677304_ogen.nwb (subject: sub-632487)
#   Found units table with 2745 units
#   Column names: ('nn_miss_rate', 'velocity_above', 'max_drift', 'waveform_duration', 'silhouette_score', 'l_ratio', 'snr', 'cumulative_drift', 'isi_violations', 'recovery_slope', 'peak_channel_id', 'local_index', 'waveform_halfwidth', 'amplitude', 'PT_ratio', 'velocity_below', 'quality', 'firing_rate', 'd_prime', 'isolation_distance', 'nn_hit_rate', 'amplitude_cutoff', 'cluster_id', 'repolarization_slope', 'spread', 'presence_ratio', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-637542/sub-637542_ses-1211241460_ogen.nwb (subject: sub-637542)
#   Found units table with 2055 units
#   Column names: ('velocity_below', 'velocity_above', 'l_ratio', 'd_prime', 'silhouette_score', 'cluster_id', 'local_index', 'waveform_duration', 'nn_hit_rate', 'waveform_halfwidth', 'snr', 'PT_ratio', 'nn_miss_rate', 'peak_channel_id', 'quality', 'repolarization_slope', 'recovery_slope', 'isi_violations', 'amplitude_cutoff', 'spread', 'max_drift', 'firing_rate', 'amplitude', 'presence_ratio', 'cumulative_drift', 'isolation_distance', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-632485/sub-632485_ses-1203581890_probe-1_ecephys.nwb (subject: sub-632485)
#   Skipping - no units table found or empty
# Processing file: sub-632485/sub-632485_ses-1203581890_probe-2_ecephys.nwb (subject: sub-632485)
#   Skipping - no units table found or empty
# Processing file: sub-632485/sub-632485_ses-1203581890_probe-5_ecephys.nwb (subject: sub-632485)
#   Skipping - no units table found or empty
# Processing file: sub-632485/sub-632485_ses-1203581890_probe-3_ecephys.nwb (subject: sub-632485)
#   Skipping - no units table found or empty
# Processing file: sub-632485/sub-632485_ses-1203581890_probe-4_ecephys.nwb (subject: sub-632485)
#   Skipping - no units table found or empty
# Processing file: sub-632485/sub-632485_ses-1203581890_ogen.nwb (subject: sub-632485)
#   Found units table with 2272 units
#   Column names: ('nn_miss_rate', 'l_ratio', 'waveform_halfwidth', 'isi_violations', 'velocity_above', 'd_prime', 'cumulative_drift', 'PT_ratio', 'max_drift', 'quality', 'amplitude_cutoff', 'velocity_below', 'spread', 'silhouette_score', 'presence_ratio', 'amplitude', 'cluster_id', 'waveform_duration', 'firing_rate', 'snr', 'local_index', 'nn_hit_rate', 'recovery_slope', 'repolarization_slope', 'peak_channel_id', 'isolation_distance', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-637909/sub-637909_ses-1212569512_ogen.nwb (subject: sub-637909)
#   Found units table with 2414 units
#   Column names: ('recovery_slope', 'snr', 'spread', 'isi_violations', 'isolation_distance', 'max_drift', 'amplitude_cutoff', 'cluster_id', 'silhouette_score', 'presence_ratio', 'nn_miss_rate', 'd_prime', 'waveform_halfwidth', 'amplitude', 'firing_rate', 'local_index', 'velocity_above', 'nn_hit_rate', 'waveform_duration', 'velocity_below', 'l_ratio', 'peak_channel_id', 'cumulative_drift', 'PT_ratio', 'quality', 'repolarization_slope', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-637908/sub-637908_ses-1213341633_probe-0_ecephys.nwb (subject: sub-637908)
#   Skipping - no units table found or empty
# Processing file: sub-637908/sub-637908_ses-1213341633_probe-1_ecephys.nwb (subject: sub-637908)
#   Skipping - no units table found or empty
# Processing file: sub-637908/sub-637908_ses-1213341633_probe-5_ecephys.nwb (subject: sub-637908)
#   Skipping - no units table found or empty
# Processing file: sub-637908/sub-637908_ses-1213341633_probe-3_ecephys.nwb (subject: sub-637908)
#   Skipping - no units table found or empty
# Processing file: sub-637908/sub-637908_ses-1213341633_probe-2_ecephys.nwb (subject: sub-637908)
#   Skipping - no units table found or empty
# Processing file: sub-637908/sub-637908_ses-1213341633_ogen.nwb (subject: sub-637908)
#   Found units table with 2558 units
#   Column names: ('amplitude_cutoff', 'presence_ratio', 'waveform_duration', 'amplitude', 'silhouette_score', 'PT_ratio', 'recovery_slope', 'peak_channel_id', 'cumulative_drift', 'quality', 'velocity_below', 'l_ratio', 'nn_miss_rate', 'max_drift', 'firing_rate', 'velocity_above', 'waveform_halfwidth', 'nn_hit_rate', 'd_prime', 'local_index', 'snr', 'cluster_id', 'isolation_distance', 'spread', 'repolarization_slope', 'isi_violations', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-640507/sub-640507_ses-1217213788_ogen.nwb (subject: sub-640507)
#   Found units table with 2378 units
#   Column names: ('isi_violations', 'snr', 'cluster_id', 'cumulative_drift', 'recovery_slope', 'repolarization_slope', 'local_index', 'firing_rate', 'velocity_below', 'waveform_halfwidth', 'peak_channel_id', 'presence_ratio', 'd_prime', 'nn_hit_rate', 'amplitude_cutoff', 'max_drift', 'spread', 'velocity_above', 'amplitude', 'isolation_distance', 'PT_ratio', 'silhouette_score', 'l_ratio', 'nn_miss_rate', 'waveform_duration', 'quality', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-647836/sub-647836_ses-1227858756_ogen.nwb (subject: sub-647836)
#   Found units table with 2170 units
#   Column names: ('local_index', 'spread', 'quality', 'firing_rate', 'peak_channel_id', 'd_prime', 'repolarization_slope', 'waveform_duration', 'cumulative_drift', 'velocity_below', 'isolation_distance', 'l_ratio', 'PT_ratio', 'silhouette_score', 'velocity_above', 'isi_violations', 'snr', 'presence_ratio', 'nn_miss_rate', 'cluster_id', 'waveform_halfwidth', 'recovery_slope', 'max_drift', 'amplitude', 'amplitude_cutoff', 'nn_hit_rate', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-645324/sub-645324_ses-1226788689_ogen.nwb (subject: sub-645324)
#   Found units table with 3101 units
#   Column names: ('d_prime', 'cumulative_drift', 'firing_rate', 'l_ratio', 'silhouette_score', 'presence_ratio', 'cluster_id', 'waveform_halfwidth', 'nn_hit_rate', 'local_index', 'repolarization_slope', 'recovery_slope', 'max_drift', 'isi_violations', 'amplitude', 'velocity_above', 'amplitude_cutoff', 'PT_ratio', 'snr', 'nn_miss_rate', 'spread', 'waveform_duration', 'quality', 'peak_channel_id', 'isolation_distance', 'velocity_below', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-645495/sub-645495_ses-1224930300_ogen.nwb (subject: sub-645495)
#   Found units table with 3047 units
#   Column names: ('l_ratio', 'max_drift', 'quality', 'silhouette_score', 'cumulative_drift', 'amplitude', 'PT_ratio', 'recovery_slope', 'repolarization_slope', 'local_index', 'presence_ratio', 'nn_hit_rate', 'amplitude_cutoff', 'isolation_distance', 'snr', 'spread', 'firing_rate', 'cluster_id', 'waveform_duration', 'velocity_below', 'peak_channel_id', 'nn_miss_rate', 'd_prime', 'isi_violations', 'waveform_halfwidth', 'velocity_above', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-642507/sub-642507_ses-1221092548_ogen.nwb (subject: sub-642507)
#   Found units table with 3017 units
#   Column names: ('velocity_above', 'firing_rate', 'presence_ratio', 'quality', 'isi_violations', 'isolation_distance', 'd_prime', 'waveform_halfwidth', 'nn_miss_rate', 'repolarization_slope', 'amplitude', 'PT_ratio', 'peak_channel_id', 'waveform_duration', 'recovery_slope', 'spread', 'snr', 'velocity_below', 'cluster_id', 'local_index', 'silhouette_score', 'max_drift', 'nn_hit_rate', 'amplitude_cutoff', 'cumulative_drift', 'l_ratio', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-649324/sub-649324_ses-1233182025_ogen.nwb (subject: sub-649324)
#   Found units table with 2415 units
#   Column names: ('velocity_above', 'amplitude_cutoff', 'isi_violations', 'peak_channel_id', 'repolarization_slope', 'amplitude', 'l_ratio', 'recovery_slope', 'presence_ratio', 'spread', 'nn_hit_rate', 'silhouette_score', 'waveform_halfwidth', 'nn_miss_rate', 'velocity_below', 'isolation_distance', 'PT_ratio', 'cumulative_drift', 'waveform_duration', 'quality', 'snr', 'max_drift', 'local_index', 'firing_rate', 'cluster_id', 'd_prime', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-645322/sub-645322_ses-1226526314_ogen.nwb (subject: sub-645322)
#   Found units table with 3065 units
#   Column names: ('silhouette_score', 'isi_violations', 'd_prime', 'presence_ratio', 'amplitude_cutoff', 'nn_hit_rate', 'velocity_below', 'waveform_duration', 'max_drift', 'firing_rate', 'cumulative_drift', 'recovery_slope', 'local_index', 'isolation_distance', 'snr', 'velocity_above', 'repolarization_slope', 'l_ratio', 'cluster_id', 'amplitude', 'waveform_halfwidth', 'PT_ratio', 'peak_channel_id', 'nn_miss_rate', 'quality', 'spread', 'spike_times', 'spike_amplitudes', 'waveform_mean')
# Processing file: sub-649323/sub-649323_ses-1232959154_ogen.nwb (subject: sub-649323)
#   Found units table with 2379 units
#   Column names: ('l_ratio', 'local_index', 'amplitude_cutoff', 'waveform_duration', 'max_drift', 'silhouette_score', 'd_prime', 'PT_ratio', 'firing_rate', 'velocity_above', 'nn_miss_rate', 'isi_violations', 'repolarization_slope', 'spread', 'quality', 'velocity_below', 'waveform_halfwidth', 'cluster_id', 'isolation_distance', 'amplitude', 'nn_hit_rate', 'presence_ratio', 'recovery_slope', 'cumulative_drift', 'peak_channel_id', 'snr', 'spike_times', 'spike_amplitudes', 'waveform_mean')
#
# Processed 14 subjects with units tables
# Available subjects: ['sub-621890', 'sub-632487', 'sub-637542', 'sub-632485', 'sub-637909', 'sub-637908', 'sub-640507', 'sub-647836', 'sub-645324', 'sub-645495', 'sub-642507', 'sub-649324', 'sub-645322', 'sub-649323']

# %% [markdown]
# ### The cell below is for the final script to download all the units from the groundtruth dateset. It should not be executed currently, so should be kept as commented out.

# %%
# # HIPPIE-Compatible Unit Export from DANDI Dataset 000253

# # 📦 SECTION 1: Imports and Configuration
# import os
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from dandi.dandiapi import DandiAPIClient
# from pynwb import NWBHDF5IO
# from pathlib import Path

# # 📁 Create local download path
# dandi_id = '000253'
# download_path = f'./dandi_{dandi_id}_nwb/'
# os.makedirs(download_path, exist_ok=True)

# # 🔽 SECTION 2: Download NWB Files from DANDI
# with DandiAPIClient() as client:
#     assets = client.get_dandiset(dandi_id, 'draft').get_assets()
#     for asset in assets:
#         asset.download(download_path)

# # 📂 SECTION 3: Load NWB Files and Extract Units
# nwb_files = list(Path(download_path).glob("*.nwb"))
# unit_data = []

# for file in nwb_files:
#     with NWBHDF5IO(file, 'r') as io:
#         nwbfile = io.read()
#         if nwbfile.units is None:
#             continue
#         units_table = nwbfile.units.to_dataframe()
#         unit_data.append((file.name, nwbfile, units_table))

# # 📈 SECTION 4a: Extract Average Waveforms
# waveform_rows = []

# for file_name, nwbfile, units_df in unit_data:
#     for unit_idx, row in units_df.iterrows():
#         waveforms = row.get('waveforms', None)
#         if waveforms is not None and isinstance(waveforms, np.ndarray):
#             mean_wave = np.mean(waveforms, axis=0)
#             waveform_rows.append([unit_idx] + list(mean_wave))

# waveform_df = pd.DataFrame(waveform_rows)
# if not waveform_df.empty:
#     waveform_df.columns = ['unit_id'] + [f'chan_{i}' for i in range(waveform_df.shape[1] - 1)]
#     waveform_df.to_csv('waveforms.csv', index=False)
# else:
#     print("⚠️ No waveform data found.")

# # ⏱ SECTION 4b: Extract ISI Histogram per Unit
# isi_rows = []

# for _, _, units_df in unit_data:
#     for unit_idx, row in units_df.iterrows():
#         spike_times = row['spike_times']
#         if isinstance(spike_times, np.ndarray) and len(spike_times) > 2:
#             isis = np.diff(spike_times)
#             hist, _ = np.histogram(isis, bins=50, range=(0, 1.0))
#             isi_rows.append([unit_idx] + list(hist))

# isi_df = pd.DataFrame(isi_rows)
# if not isi_df.empty:
#     isi_df.columns = ['unit_id'] + [f'b{i}' for i in range(50)]
#     isi_df.to_csv('isis.csv', index=False)
# else:
#     print("⚠️ No ISI data found.")

# # 🧾 SECTION 4c: Extract Unit Metadata
# meta_rows = []

# for file_name, nwbfile, units_df in unit_data:
#     for unit_idx, row in units_df.iterrows():
#         meta_rows.append({
#             'unit_id': unit_idx,
#             'source_file': file_name,
#             'location': row.get('location', 'unknown'),
#             'electrode_group': row.get('electrode_group', 'unknown'),
#         })

# metadata_df = pd.DataFrame(meta_rows)
# if not metadata_df.empty:
#     metadata_df.to_csv('metadata.csv', index=False)
# else:
#     print("⚠️ No metadata found.")

# # ✅ SECTION 5: Sanity Checks (Optional)
# if not waveform_df.empty:
#     print("waveforms.csv shape:", waveform_df.shape)
# if not isi_df.empty:
#     print("isis.csv shape:", isi_df.shape)
# if not metadata_df.empty:
#     print("metadata.csv shape:", metadata_df.shape)

# # Example plot of ISI histogram
# if not isi_df.empty:
#     isi_df.iloc[0, 1:].plot(kind='bar', title=f"ISI Histogram for Unit {isi_df.iloc[0]['unit_id']}")
#     plt.xlabel("ISI Bin")
#     plt.ylabel("Count")
#     plt.tight_layout()
#     plt.show()
# else:
#     print("⚠️ Skipping plot: no ISI data to display.")
